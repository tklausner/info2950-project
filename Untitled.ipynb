# %% [markdown]
# # INFO 2950 Project
#
# ### Authors: Teddy Klausner, Spencer Pettee, Sasha Miranda, and Ben Polson

# %% [markdown]
# ## Hypothesis:

# %% [markdown]
# ## Data Collection:

# %%
## load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

## load data
data = pd.read_csv("3i-index-data.csv",  encoding='latin-1')

# %%
for c in data:
    print(c)
    print(data[c].describe(), '\n')
# Out:
# ISO
# count     118
# unique    118
# top        MW
# freq        1
# Name: ISO, dtype: object
#
# Country/Group
# count         119
# unique        119
# top       Hungary
# freq            1
# Name: Country/Group, dtype: object
#
# 1.1.1) Internet users / % of households
# count    119.000000
# mean      58.017353
# std       31.108138
# min        0.300000
# 25%       24.950000
# 50%       67.700000
# 75%       85.900000
# max      100.000000
# Name: 1.1.1) Internet users / % of households, dtype: float64
#
# 1.1.2) Fixed-line broadband subscribers / Per 100 inhabitants
# count    119.000000
# mean      14.896832
# std       13.869953
# min        0.030000
# 25%        1.655000
# 50%       10.936000
# 75%       27.840000
# max       44.770000
# Name: 1.1.2) Fixed-line broadband subscribers / Per 100 inhabitants, dtype: float64
#
# 1.1.3) Mobile subscribers / Per 100 inhabitants
# count    119.000000
# mean     106.683218
# std       25.049091
# min       37.200000
# 25%       95.800000
# 50%      115.000000
# 75%      129.950000
# max      130.000000
# Name: 1.1.3) Mobile subscribers / Per 100 inhabitants, dtype: float64
#
# 1.1.4) Gender gap in internet access / % difference
# count    119.000000
# mean      13.117025
# std       15.939568
# min      -14.000000
# 25%        2.050000
# 50%        8.300000
# 75%       21.686500
# max       70.600000
# Name: 1.1.4) Gender gap in internet access / % difference, dtype: float64
#
# 1.1.5) Gender gap in mobile phone access / % difference
# count    119.000000
# mean       6.561605
# std        9.432373
# min       -3.900000
# 25%        1.000000
# 50%        3.800000
# 75%       10.902000
# max       68.200000
# Name: 1.1.5) Gender gap in mobile phone access / % difference, dtype: float64
#
# 1.2.1) Average fixed broadband upload speed / Kbps
# count       119.000000
# mean      32974.024765
# std       34054.079659
# min        1730.000000
# 25%       10625.000000
# 50%       20670.000000
# 75%       45240.000000
# max      201540.000000
# Name: 1.2.1) Average fixed broadband upload speed / Kbps, dtype: float64
#
# 1.2.2) Average fixed broadband download speed / Kbps
# count       119.000000
# mean      49954.049118
# std       42445.982229
# min        3640.000000
# 25%       15646.304500
# 50%       33400.000000
# 75%       77850.000000
# max      193210.000000
# Name: 1.2.2) Average fixed broadband download speed / Kbps, dtype: float64
#
# 1.2.3) Average fixed broadband latency / ms
# count    119.000000
# mean      36.747286
# std       28.442779
# min        8.000000
# 25%       20.000000
# 50%       30.000000
# 75%       45.000000
# max      165.000000
# Name: 1.2.3) Average fixed broadband latency / ms, dtype: float64
#
# 1.2.4) Average mobile upload speed / Kbps
# count      119.000000
# mean     12319.530513
# std       3708.713299
# min       4460.000000
# 25%       9631.333500
# 50%      12310.250000
# 75%      14858.648500
# max      21850.000000
# Name: 1.2.4) Average mobile upload speed / Kbps, dtype: float64
#
# 1.2.5) Average mobile download speed / Kbps
# count       119.000000
# mean      29844.371723
# std       18446.455929
# min         126.000000
# 25%       15880.000000
# 50%       25090.000000
# 75%       41222.083500
# max      117790.000000
# Name: 1.2.5) Average mobile download speed / Kbps, dtype: float64
#
# 1.2.6) Average mobile latency / ms
# count    119.000000
# mean      42.136529
# std       14.375821
# min       24.000000
# 25%       32.000000
# 50%       40.000000
# 75%       50.000000
# max      114.000000
# Name: 1.2.6) Average mobile latency / ms, dtype: float64
#
# 1.2.7) Bandwidth capacity / Bit/s per Internet user
# count    1.190000e+02
# mean     1.727338e+05
# std      7.711033e+05
# min      5.400000e+02
# 25%      1.972300e+04
# 50%      4.888600e+04
# 75%      1.134866e+05
# max      8.203481e+06
# Name: 1.2.7) Bandwidth capacity / Bit/s per Internet user, dtype: float64
#
# 1.3.1) Network coverage (min. 2G) / % of population
# count    119.000000
# mean      96.333731
# std        6.239504
# min       53.650000
# 25%       95.797500
# 50%       99.000000
# 75%       99.900000
# max      100.000000
# Name: 1.3.1) Network coverage (min. 2G) / % of population, dtype: float64
#
# 1.3.2) Network coverage (min. 3G) / % of population
# count    119.000000
# mean      89.661496
# std       13.920080
# min       33.000000
# 25%       85.000000
# 50%       96.300000
# 75%       99.400000
# max      100.000000
# Name: 1.3.2) Network coverage (min. 3G) / % of population, dtype: float64
#
# 1.3.3) Network coverage (min. 4G) / % of population
# count    119.000000
# mean      75.280403
# std       27.207410
# min        0.000000
# 25%       57.500000
# 50%       88.020000
# 75%       98.131500
# max      100.000000
# Name: 1.3.3) Network coverage (min. 4G) / % of population, dtype: float64
#
# 1.3.4) 5G deployment / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       0.768487
# std        0.708550
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: 1.3.4) 5G deployment / Qualitative rating 0-2, 2=best, dtype: float64
#
# 1.3.5) Government initiatives to make Wi-Fi available / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.647639
# std        0.692760
# min        0.000000
# 25%        1.841000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 1.3.5) Government initiatives to make Wi-Fi available / Qualitative rating 0-2, 2=best, dtype: float64
#
# 1.3.6) Private sector initiatives to make Wi-Fi available / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.425361
# std        0.794085
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 1.3.6) Private sector initiatives to make Wi-Fi available / Qualitative rating 0-2, 2=best, dtype: float64
#
# 1.3.7) Internet exchange points / Number of IXPs per 10 million inhabitants
# count    119.000000
# mean       2.450950
# std        3.933664
# min        0.000000
# 25%        0.340000
# 50%        1.110000
# 75%        2.875500
# max       30.330000
# Name: 1.3.7) Internet exchange points / Number of IXPs per 10 million inhabitants, dtype: float64
#
# 1.4.1) Urban electricity access / % of population
# count    119.000000
# mean      93.946706
# std       13.178000
# min       16.700000
# 25%       96.150000
# 50%      100.000000
# 75%      100.000000
# max      100.000000
# Name: 1.4.1) Urban electricity access / % of population, dtype: float64
#
# 1.4.2) Rural electricity access / % of population
# count    119.000000
# mean      80.312252
# std       31.143634
# min        1.600000
# 25%       71.050000
# 50%       99.200000
# 75%      100.000000
# max      100.000000
# Name: 1.4.2) Rural electricity access / % of population, dtype: float64
#
# 2.1.1) Smartphone cost (handset) / Score of 0-100, 100=most affordable
# count    119.000000
# mean      45.467118
# std       21.024788
# min        0.000000
# 25%       31.481000
# 50%       45.600000
# 75%       62.183500
# max       99.500000
# Name: 2.1.1) Smartphone cost (handset) / Score of 0-100, 100=most affordable, dtype: float64
#
# 2.1.2) Mobile phone cost (prepaid tariff) / % of monthly GNI per capita
# count    119.000000
# mean       2.837042
# std        4.016211
# min        0.100000
# 25%        0.635000
# 50%        1.260000
# 75%        3.110000
# max       19.780000
# Name: 2.1.2) Mobile phone cost (prepaid tariff) / % of monthly GNI per capita, dtype: float64
#
# 2.1.3) Mobile phone cost (postpaid tariff) / % of monthly GNI per capita
# count    119.000000
# mean       3.839059
# std        5.883196
# min        0.000000
# 25%        0.690000
# 50%        1.470000
# 75%        3.946500
# max       35.580000
# Name: 2.1.3) Mobile phone cost (postpaid tariff) / % of monthly GNI per capita, dtype: float64
#
# 2.1.4) Fixed-line monthly broadband cost / % of monthly GNI per capita
# count    119.000000
# mean      18.472252
# std       66.330109
# min        0.350000
# 25%        1.215000
# 50%        2.550000
# 75%        9.025000
# max      600.000000
# Name: 2.1.4) Fixed-line monthly broadband cost / % of monthly GNI per capita, dtype: float64
#
# 2.2.1) Average revenue per user (ARPU, annualized) / USD
# count    119.00000
# mean     139.81605
# std      127.41791
# min        8.40000
# 25%       47.16650
# 50%       90.00000
# 75%      213.50000
# max      652.80000
# Name: 2.2.1) Average revenue per user (ARPU, annualized) / USD, dtype: float64
#
# 2.2.2) Wireless operators' market share / HHI score (0-10,000)
# count      119.000000
# mean      3851.717983
# std       1283.292534
# min       2455.000000
# 25%       3223.272500
# 50%       3521.000000
# 75%       4152.761000
# max      10000.000000
# Name: 2.2.2) Wireless operators' market share / HHI score (0-10,000), dtype: float64
#
# 2.2.3) Broadband operators' market share / HHI score (0-10,000)
# count      119.000000
# mean      4585.430521
# std       2086.589253
# min       1482.000000
# 25%       3044.613500
# 50%       4070.000000
# 75%       5771.000000
# max      10000.000000
# Name: 2.2.3) Broadband operators' market share / HHI score (0-10,000), dtype: float64
#
# 3.1.1) Availability of basic information in the local language / Qualitative rating 0-3, 3=best
# count    119.000000
# mean       2.758487
# std        0.471754
# min        1.000000
# 25%        2.906000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: 3.1.1) Availability of basic information in the local language / Qualitative rating 0-3, 3=best, dtype: float64
#
# 3.1.2) Concentration of websites using country-level domains / Qualitative rating 0-3, 3=best
# count    119.000000
# mean       2.004521
# std        0.997780
# min        0.000000
# 25%        1.450000
# 50%        2.000000
# 75%        3.000000
# max        3.000000
# Name: 3.1.2) Concentration of websites using country-level domains / Qualitative rating 0-3, 3=best, dtype: float64
#
# 3.1.3) Availability of e-Government services in the local language / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.530529
# std        0.608372
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 3.1.3) Availability of e-Government services in the local language / Qualitative rating 0-2, 2=best, dtype: float64
#
# 3.2.1) e-Finance content / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.729345
# std        0.419262
# min        1.000000
# 25%        1.431000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 3.2.1) e-Finance content / Qualitative rating 0-2, 2=best, dtype: float64
#
# 3.2.2) Value of e-finance / %
# count    119.000000
# mean      50.685950
# std       14.393432
# min       16.000000
# 25%       40.000000
# 50%       50.805000
# 75%       61.450000
# max       86.000000
# Name: 3.2.2) Value of e-finance / %, dtype: float64
#
# 3.2.3) e-Health content / Qualitative rating 0-3, 3=best
# count    119.000000
# mean       2.234429
# std        0.762275
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        3.000000
# Name: 3.2.3) e-Health content / Qualitative rating 0-3, 3=best, dtype: float64
#
# 3.2.4) Value of e-health / %
# count    119.000000
# mean      60.400731
# std       10.719897
# min       32.000000
# 25%       54.000000
# 50%       62.000000
# 75%       68.000000
# max       88.000000
# Name: 3.2.4) Value of e-health / %, dtype: float64
#
# 3.2.5) e-Entertainment usage / %
# count    119.000000
# mean      92.783445
# std        3.992910
# min       80.000000
# 25%       91.089000
# 50%       94.000000
# 75%       96.000000
# max      100.000000
# Name: 3.2.5) e-Entertainment usage / %, dtype: float64
#
# 3.2.6) e-Commerce content / Score of 0-100, 100=best
# count    119.000000
# mean      59.497017
# std       23.124206
# min        9.000000
# 25%       40.109000
# 50%       59.400000
# 75%       81.750000
# max       96.400000
# Name: 3.2.6) e-Commerce content / Score of 0-100, 100=best, dtype: float64
#
# 3.2.7) Value of e-Commerce / %
# count    119.000000
# mean      59.685866
# std       11.949655
# min       34.000000
# 25%       52.000000
# 50%       60.000000
# 75%       68.000000
# max       96.000000
# Name: 3.2.7) Value of e-Commerce / %, dtype: float64
#
# 3.2.8) Open data policies / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.398244
# std        0.761182
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 3.2.8) Open data policies / Qualitative rating 0-2, 2=best, dtype: float64
#
# 4.1.1) Level of literacy / % of population
# count    119.000000
# mean      88.241723
# std       14.114991
# min       41.200000
# 25%       79.800000
# 50%       95.000000
# 75%       99.219000
# max      100.000000
# Name: 4.1.1) Level of literacy / % of population, dtype: float64
#
# 4.1.2) Educational attainment / Years of schooling
# count    119.000000
# mean       8.975185
# std        2.893829
# min        1.600000
# 25%        6.704000
# 50%        9.300000
# 75%       11.500000
# max       14.100000
# Name: 4.1.2) Educational attainment / Years of schooling, dtype: float64
#
# 4.1.3) Support for digital literacy / Qualitative rating 0-3, 3=best
# count    119.000000
# mean       2.438504
# std        0.839462
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: 4.1.3) Support for digital literacy / Qualitative rating 0-3, 3=best, dtype: float64
#
# 4.1.4) Level of web accessibility / Qualitative rating 0-4, 4=best
# count    119.000000
# mean       1.489739
# std        1.024199
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.000000
# max        4.000000
# Name: 4.1.4) Level of web accessibility / Qualitative rating 0-4, 4=best, dtype: float64
#
# 4.2.1) Privacy regulations / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.695202
# std        0.656841
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 4.2.1) Privacy regulations / Qualitative rating 0-2, 2=best, dtype: float64
#
# 4.2.2) Trust in online privacy / %
# count    119.000000
# mean      52.586076
# std       12.967983
# min       16.000000
# 25%       46.000000
# 50%       54.000000
# 75%       61.686500
# max       84.000000
# Name: 4.2.2) Trust in online privacy / %, dtype: float64
#
# 4.2.3) Trust in Government websites and apps / %
# count    119.000000
# mean      47.297580
# std        9.601891
# min       20.000000
# 25%       42.000000
# 50%       47.236000
# 75%       54.000000
# max       78.000000
# Name: 4.2.3) Trust in Government websites and apps / %, dtype: float64
#
# 4.2.4) Trust in Non-government websites and apps / %
# count    119.000000
# mean      27.384916
# std        8.455579
# min        2.000000
# 25%       22.000000
# 50%       27.800000
# 75%       32.000000
# max       50.000000
# Name: 4.2.4) Trust in Non-government websites and apps / %, dtype: float64
#
# 4.2.5) Trust in information from social media / %
# count    119.000000
# mean      27.665571
# std        9.055091
# min        8.000000
# 25%       22.000000
# 50%       26.000000
# 75%       32.000000
# max       56.000000
# Name: 4.2.5) Trust in information from social media / %, dtype: float64
#
# 4.2.6) e-Commerce safety / %
# count    119.000000
# mean      55.760496
# std       10.882797
# min       27.100000
# 25%       49.866500
# 50%       56.000000
# 75%       61.450000
# max       88.000000
# Name: 4.2.6) e-Commerce safety / %, dtype: float64
#
# 4.3.1) National female e-inclusion policies / Qualitative rating 0-4, 4=best
# count    119.000000
# mean       1.956017
# std        1.285865
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: 4.3.1) National female e-inclusion policies / Qualitative rating 0-4, 4=best, dtype: float64
#
# 4.3.1.1) Comprehensive female e-inclusion plan / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.205731
# std        0.864760
# min        0.000000
# 25%        0.000000
# 50%        1.500000
# 75%        2.000000
# max        2.000000
# Name: 4.3.1.1) Comprehensive female e-inclusion plan / Qualitative rating 0-2, 2=best, dtype: float64
#
# 4.3.1.2) Female digital skills training plan / Qualitative rating 0-1, 1=best
# count    119.000000
# mean       0.333891
# std        0.436556
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: 4.3.1.2) Female digital skills training plan / Qualitative rating 0-1, 1=best, dtype: float64
#
# 4.3.1.3) Female STEM education plan / Qualitative rating 0-1, 1=best
# count    119.000000
# mean       0.416361
# std        0.461880
# min        0.000000
# 25%        0.000000
# 50%        0.100000
# 75%        1.000000
# max        1.000000
# Name: 4.3.1.3) Female STEM education plan / Qualitative rating 0-1, 1=best, dtype: float64
#
# 4.3.2) Government e-inclusion strategy / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.461134
# std        0.692187
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 4.3.2) Government e-inclusion strategy / Qualitative rating 0-2, 2=best, dtype: float64
#
# 4.3.3) National broadband strategy / Qualitative rating 0-3, 3=best
# count    119.000000
# mean       2.118303
# std        0.957979
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        3.000000
# Name: 4.3.3) National broadband strategy / Qualitative rating 0-3, 3=best, dtype: float64
#
# 4.3.4) Funding for broadband buildout / Qualitative rating 0-1, 1=best
# count    119.000000
# mean       0.904580
# std        0.279126
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: 4.3.4) Funding for broadband buildout / Qualitative rating 0-1, 1=best, dtype: float64
#
# 4.3.5) Spectrum policy approach / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.573227
# std        0.609496
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 4.3.5) Spectrum policy approach / Qualitative rating 0-2, 2=best, dtype: float64
#
# 4.3.5.1) Technology-neutrality policy for spectrum use / Qualitative rating 0-1, 1=best
# count    119.000000
# mean       0.838857
# std        0.340306
# min        0.000000
# 25%        0.909500
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: 4.3.5.1) Technology-neutrality policy for spectrum use / Qualitative rating 0-1, 1=best, dtype: float64
#
# 4.3.5.2) Unlicensed spectrum policy / Qualitative rating 0-1, 1=best
# count    119.000000
# mean       0.734370
# std        0.411316
# min        0.000000
# 25%        0.500000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: 4.3.5.2) Unlicensed spectrum policy / Qualitative rating 0-1, 1=best, dtype: float64
#
# 4.3.6) National digital identification system / Qualitative rating 0-2, 2=best
# count    119.000000
# mean       1.812059
# std        0.525137
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: 4.3.6) National digital identification system / Qualitative rating 0-2, 2=best, dtype: float64
#
# 4.3.7) Government efforts to promote 5G / Qualitative rating 0-3, 3=best
# count    119.000000
# mean       1.213261
# std        1.283000
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max        3.000000
# Name: 4.3.7) Government efforts to promote 5G / Qualitative rating 0-3, 3=best, dtype: float64
#
# BG1) Nominal GDP / USD billions
# count      119.000000
# mean       878.594345
# std       2516.895337
# min          3.100000
# 25%         41.800000
# 50%        224.780000
# 75%        571.000000
# max      20580.300000
# Name: BG1) Nominal GDP / USD billions, dtype: float64
#
# BG2) Population / Millions
# count     119.000000
# mean       72.428059
# std       184.058350
# min         1.300000
# 25%         9.208500
# 50%        25.900000
# 75%        58.100000
# max      1385.000000
# Name: BG2) Population / Millions, dtype: float64
#
# BG3) Urban population / % of total population
# count    119.000000
# mean      62.304168
# std       22.163671
# min       13.000000
# 25%       48.600000
# 50%       63.200000
# 75%       80.350000
# max      100.000000
# Name: BG3) Urban population / % of total population, dtype: float64
#
# BG4) GNI per capita / US$ per person
# count      119.000000
# mean     15786.116992
# std      17705.843203
# min        280.000000
# 25%       2275.000000
# 50%       7750.000000
# 75%      21785.000000
# max      62850.000000
# Name: BG4) GNI per capita / US$ per person, dtype: float64
#
# BG5) GINI coefficient / Score, 0-100; 0 is perfect equality; 100 is perfect inequality
# count    119.000000
# mean      38.736546
# std        7.019758
# min       26.500000
# 25%       34.100000
# 50%       37.400000
# 75%       42.813500
# max       63.000000
# Name: BG5) GINI coefficient / Score, 0-100; 0 is perfect equality; 100 is perfect inequality, dtype: float64
#
# BG6) Population under the poverty line / % of population
# count    119.000000
# mean       4.231647
# std        7.633147
# min        0.000000
# 25%        0.200000
# 50%        0.600000
# 75%        4.450000
# max       39.000000
# Name: BG6) Population under the poverty line / % of population, dtype: float64
#
# BG7) Total electricity access / % of population
# count    119.000000
# mean      85.831126
# std       24.601585
# min       10.600000
# 25%       84.600000
# 50%       99.725000
# 75%      100.000000
# max      100.000000
# Name: BG7) Total electricity access / % of population, dtype: float64
#
# BG8) Cable landing stations / Number of cable landing stations per 10 million inhabitants
# count    119.000000
# mean       7.731748
# std       12.916241
# min        0.000000
# 25%        0.600000
# 50%        2.500000
# 75%        8.600000
# max       73.000000
# Name: BG8) Cable landing stations / Number of cable landing stations per 10 million inhabitants, dtype: float64
#
# BG9) Percentage of schools with Internet access / % of schools
# count    119.000000
# mean      63.236891
# std       34.194977
# min        0.700000
# 25%       31.500000
# 50%       72.800000
# 75%       96.250000
# max      100.000000
# Name: BG9) Percentage of schools with Internet access / % of schools, dtype: float64
#
# BG10) Global Peace Index / Score, 1-5; 1 = best
# count    119.000000
# mean       2.024092
# std        0.409532
# min        1.200000
# 25%        1.708500
# 50%        2.000000
# 75%        2.300000
# max        3.100000
# Name: BG10) Global Peace Index / Score, 1-5; 1 = best, dtype: float64
#
# BG11) Democracy Index / Score, 0-10; 10 = best
# count    119.000000
# mean       5.659277
# std        2.013887
# min        1.900000
# 25%        3.800000
# 50%        5.800000
# 75%        7.200000
# max        9.400000
# Name: BG11) Democracy Index / Score, 0-10; 10 = best, dtype: float64
#
# BG12) Corruption Perceptions Index / Score, 0-100; 100 = best
# count    119.000000
# mean      45.363521
# std       18.268157
# min       16.000000
# 25%       32.000000
# 50%       41.000000
# 75%       58.000000
# max       88.000000
# Name: BG12) Corruption Perceptions Index / Score, 0-100; 100 = best, dtype: float64
#
# BG13) EIU Business Environment Rankings / Score, 1-10, 10 = high
# count    119.000000
# mean       6.060504
# std        1.269104
# min        3.500000
# 25%        5.100000
# 50%        5.900000
# 75%        6.950000
# max        8.500000
# Name: BG13) EIU Business Environment Rankings / Score, 1-10, 10 = high, dtype: float64
#
# BG14) UN E-Government Development Index / Score, 0-1; 1 = best
# count    119.000000
# mean       0.610328
# std        0.191128
# min        0.200000
# 25%        0.421000
# 50%        0.638000
# 75%        0.800000
# max        0.900000
# Name: BG14) UN E-Government Development Index / Score, 0-1; 1 = best, dtype: float64
#
# BG15) Internet users (population) / Millions
# count    119.000000
# mean      37.761639
# std       88.582303
# min        0.290000
# 25%        4.335000
# 50%       12.754000
# 75%       32.445000
# max      771.610000
# Name: BG15) Internet users (population) / Millions, dtype: float64
#
# BG16) Offline population / Millions
# count    119.000000
# mean      34.540882
# std      104.838811
# min        0.010000
# 25%        2.285000
# 50%        8.685000
# 75%       25.385000
# max      877.500000
# Name: BG16) Offline population / Millions, dtype: float64
#
# BG17) Internet access gender gap / Difference in percentage points
# count    119.000000
# mean       6.004227
# std        6.197145
# min       -7.000000
# 25%        2.000000
# 50%        5.000000
# 75%        9.113500
# max       24.000000
# Name: BG17) Internet access gender gap / Difference in percentage points, dtype: float64
#
# BG18) Mobile phone access gender gap / Difference in percentage points
# count    119.000000
# mean       5.189597
# std        7.466430
# min       -3.000000
# 25%        1.000000
# 50%        3.000000
# 75%        8.600000
# max       58.000000
# Name: BG18) Mobile phone access gender gap / Difference in percentage points, dtype: float64
#
# BG19) Internet users (percent of population) / % of population
# count    119.000000
# mean      60.169420
# std       27.064786
# min        2.700000
# 25%       34.713500
# 50%       65.000000
# 75%       82.150000
# max       99.700000
# Name: BG19) Internet users (percent of population) / % of population, dtype: float64
#
# BG20) Male internet users / % of male population
# count    119.000000
# mean      64.714151
# std       23.182349
# min       15.000000
# 25%       46.000000
# 50%       64.225000
# 75%       85.916500
# max       99.500000
# Name: BG20) Male internet users / % of male population, dtype: float64
#
# BG21) Female internet users / % of female population
# count    119.000000
# mean      58.709908
# std       26.312522
# min       10.000000
# 25%       37.979000
# 50%       60.000000
# 75%       81.437500
# max       99.800000
# Name: BG21) Female internet users / % of female population, dtype: float64
#
# BG22) Male mobile phone subscribers / % of male population
# count    119.000000
# mean      85.883454
# std       11.750173
# min       40.000000
# 25%       81.450000
# 50%       89.000000
# 75%       94.000000
# max      100.000000
# Name: BG22) Male mobile phone subscribers / % of male population, dtype: float64
#
# BG23) Female mobile phone subscribers / % of female population
# count    119.000000
# mean      80.688580
# std       15.277522
# min       27.000000
# 25%       73.000000
# 50%       85.000000
# 75%       91.000000
# max      100.000000
# Name: BG23) Female mobile phone subscribers / % of female population, dtype: float64
#
# BG24) Total fixed line broadband subscribers / Number of subscriptions
# count    1.190000e+02
# mean     1.076183e+07
# std      3.984772e+07
# min      3.935000e+03
# 25%      2.354810e+05
# 50%      1.901306e+06
# 75%      7.897525e+06
# max      4.073820e+08
# Name: BG24) Total fixed line broadband subscribers / Number of subscriptions, dtype: float64
